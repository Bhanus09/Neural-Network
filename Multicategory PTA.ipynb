# %%
import os
from os import path
import struct
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_idx(filename):
    with open(filename, 'rb') as f:
        zero, data_type, dims = struct.unpack('>HBB', f.read(4))
        shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
        return np.fromstring(f.read(), dtype=np.uint8).reshape(shape)

# %%
# Data Source: http://yann.lecun.com/exdb/mnist/
train_data = read_idx('/content/drive/My Drive/Colab Notebooks/Neural network /Homework/Homework-2/train-images.idx3-ubyte')
train_labels = read_idx('/content/drive/My Drive/Colab Notebooks/Neural network /Homework/Homework-2/train-labels.idx1-ubyte')
test_data = read_idx('/content/drive/My Drive/Colab Notebooks/Neural network /Homework/Homework-2/t10k-images.idx3-ubyte')
test_labels = read_idx('/content/drive/My Drive/Colab Notebooks/Neural network /Homework/Homework-2/t10k-labels.idx1-ubyte')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   """

# %%
def activation(x):
    i = 0
    y = np.empty([10,1])
    for each in x:
        if each >= 0:
            y[i] = 1.0
        else:
            y[i] = 0.0
        i += 1
    return y

# %%
def training_errors(epoch, errors):
    for i in range(n):
        xi = train_data[i]
        xi.resize(784, 1)
        v = np.matmul(w,xi)
        prediction = v.argmax(axis=0)
        actual = train_labels[i]
        if prediction != actual:
            errors[epoch] += 1
    return errors[epoch]

# %%
def update_weight(w):
    for i in range(n):
        xi = train_data[i]
        xi.resize(784, 1)
        y = np.array(activation(np.matmul(w,xi)))
        label = np.zeros((1,10)).T
        label[train_labels[i]] = 1
        difference = label - y
        xit = np.transpose(xi)
        update = learning_rate * np.matmul(difference, xit)
        w += update

# %%
def learning_weights(w, epoch, threshold, learning_rate):
    while epoch<100:
        errors.append(0)
        errors[epoch] = training_errors(epoch, errors)
        update_weight(w)
        epoch += 1
        if errors[epoch-1]/n <= threshold:
            break

# %%
def find_errors():
    test_errors = 0
    for i in range(len(test_data)):
        xi = test_data[i]
        xi.resize(784, 1)
        v = np.matmul(w ,xi)
        prediction = v.argmax(axis=0)
        actual = test_labels[i]
        if prediction != actual:
            test_errors += 1
    print ("Number of errors in test data: ", test_errors)
    print ("Percentage of test errors: ", test_errors*100/len(test_data))

# %%
def plot_graph(errors):
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(range(len(errors)), errors, c = 'green')
    plt.ylabel('Number of Misclassifications')
    plt.xlabel('Number of Epochs')
    plt.title('Errors vs Epochs')
    plt.show()

# %%
w = np.random.uniform(-1, 1, size=(10,784))
n = 50
epoch = 0
threshold = 0.0
learning_rate = 1.0
errors = []

# %%
learning_weights(w, epoch, threshold, learning_rate)
plot_graph(errors)
find_errors()
# Out:
# Number of errors in test data:  4264
# Percentage of test errors:  42.64

# %%
w = np.random.uniform(-1, 1, size=(10,784))
n = 1000
epoch = 0
threshold = 0.0
learning_rate = 1.0
errors = []

# %%
learning_weights(w, epoch, threshold, learning_rate)
plot_graph(errors)
find_errors()
# Out:
# Number of errors in test data:  1750
# Percentage of test errors:  17.5

# %%
w = np.random.uniform(-1, 1, size=(10,784))
n = 60000
epoch = 0
threshold = 0.0
learning_rate = 1.0
errors = []

# %%
learning_weights(w, epoch, threshold, learning_rate)
plot_graph(errors)
find_errors()
# Out:
# Number of errors in test data:  1465
# Percentage of test errors:  14.65

# %%
w = np.random.uniform(-1, 1, size=(10,784))
n = 60000
epoch = 0
threshold = 0.14
learning_rate = 1.0
errors = []

# %%
learning_weights(w, epoch, threshold, learning_rate)
plot_graph(errors)
find_errors()
# Out:
# Number of errors in test data:  1543
# Percentage of test errors:  15.43

# %%
w = np.random.uniform(-1, 1, size=(10,784))
n = 60000
epoch = 0
threshold = 0.14
learning_rate = 1.0
errors = []

# %%
learning_weights(w, epoch, threshold, learning_rate)
plot_graph(errors)
find_errors()
# Out:
# Number of errors in test data:  1507
# Percentage of test errors:  15.07

# %%
w = np.random.uniform(-1, 1, size=(10,784))
n = 60000
epoch = 0
threshold = 0.14
learning_rate = 1.0
errors = []

# %%
learning_weights(w, epoch, threshold, learning_rate)
plot_graph(errors)
find_errors()
# Out:
# Number of errors in test data:  1708
# Percentage of test errors:  17.08
